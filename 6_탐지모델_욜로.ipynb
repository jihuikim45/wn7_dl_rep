# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
data_path = './datasets/data.yaml'
model.train(data=data_path, epochs=10, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
result = model.predict('sample.png')
result[0].show()
# Out:
# image 1/1 /home/devuser/workspace/wn7_dl_rep/sample.png: 512x640 1 Paper, 2 Rocks, 2 Scissorss, 58.2ms
# Speed: 4.9ms preprocess, 58.2ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
# <PIL.Image.Image image mode=RGB size=777x593>

# %%
model = YOLO('runs/detect/train/weights/best.pt')
data_path = "datasets/data.yaml"
metrics = model.val(data=data_path)
metrics
# Out:
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 73.0±13.6 MB/s, size: 29.1 KB)
# val: Scanning /home/devuser/workspace/wn7_dl_rep/datasets/valid/labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 730768.0it/s 0.0s.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 5.1it/s 7.1s0.1s
#                    all        576        400      0.918      0.915      0.941      0.747
#                  Paper        132        139      0.907      0.921      0.951      0.746
#                   Rock        121        141      0.909      0.929      0.928      0.738
#               Scissors        116        120      0.939      0.895      0.945      0.757
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# 하이퍼파라미터 탐색 수행
model.tune(
data="./datasets/data.yaml",
epochs=5,
imgsz=640,
iterations=5, 
val=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/5 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %% [markdown]
# # YOLOv8n vs Best.pt 성능 비교

# %%
# 라이브러리 불러오기
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
# 모델 불러오기
model_base = YOLO("yolov8n.pt")   # COCO 사전학습 모델
model_best = YOLO("runs/detect/train/weights/best.pt")  # 내가 학습한 best 모델

# %%
# 비교할 이미지 리스트 정의
images = [
    "mnist/000001.jpg",   # 숫자
    "cat.png",            # 동물
    "people.jpg",         # 사람
    "car.png",            # 자동차
    "sample.jpg"          # 가위바위보
]

# %%
# 비교 함수 정의
def compare_models(img_path):
    # 원본 이미지 읽기
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 두 모델 예측
    results_base = model_base.predict(img_path, verbose=False)
    results_best = model_best.predict(img_path, verbose=False)

    # 결과 이미지 가져오기
    img_base = results_base[0].plot()
    img_best = results_best[0].plot()

    # BGR → RGB 변환
    img_base = cv2.cvtColor(img_base, cv2.COLOR_BGR2RGB)
    img_best = cv2.cvtColor(img_best, cv2.COLOR_BGR2RGB)

    # 비교 출력
    fig, axes = plt.subplots(1, 3, figsize=(15, 6))
    axes[0].imshow(img_rgb)
    axes[0].set_title("Original")
    axes[1].imshow(img_base)
    axes[1].set_title("YOLOv8n (Pretrained)")
    axes[2].imshow(img_best)
    axes[2].set_title("Best.pt (Custom)")
    for ax in axes:
        ax.axis("off")
    plt.show()

# %%
# 이미지별 비교 실행
for img in images:
    compare_models(img)

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="datasets/data.yaml",
    cfg="runs/detect/tune/best_hyperparameters.yaml",
    epochs=4,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="datasets/data.yaml",
    cfg="runs/detect/tune/best_hyperparameters.yaml",
    epochs=10,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# best_parameters.yaml
from ultralytics import YOLO

# 기본 모델 로드
model = YOLO("yolov8n.pt")

# 최적 파라미터로 학습
model.train(
    data="datasets/data.yaml",
    cfg="runs/detect/tune/best_hyperparameters.yaml",
    epochs=20,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191 🚀 Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# 테스트 이미지
img = "sample.png"

# 기본 모델 예측
model_base.predict(img, save=True, project="runs/compare", name="base")

# 학습 모델 예측
model_best.predict(img, save=True, project="runs/compare", name="best")
# Out:
# Results saved to runs/compare/base5
# Results saved to runs/compare/best5
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Paper', 1: 'Rock', 2: 'Scissors'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
# ...

# %%
import time

# 기본 모델
start = time.time()
model_base.predict(img)
print("YOLOv8n time:", time.time() - start)

# 학습 모델
start = time.time()
model_best.predict(img)
print("Best.pt time:", time.time() - start)
# Out:
# YOLOv8n time: 0.07518744468688965
# Best.pt time: 0.07036709785461426

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# 1. 학습한 best 모델 불러오기
model = YOLO("runs/detect/train/weights/best.pt")

# 2. 테스트 이미지 경로
img_path = "sample.png"   # 가위바위보

# 3. 예측 실행
results = model.predict(img_path, save=True, project="runs/test", name="rps_test")

# 4. 결과 이미지 표시
res_img = results[0].plot()                # 바운딩박스 그려진 이미지
res_img = cv2.cvtColor(res_img, cv2.COLOR_BGR2RGB)

plt.imshow(res_img)
plt.axis("off")
plt.show()

# 5. 라벨, 신뢰도 출력
for box in results[0].boxes:
    cls_id = int(box.cls[0])
    conf = float(box.conf[0])
    print(f"Class: {model.names[cls_id]}, Confidence: {conf:.4f}")
# Out:
# image 1/1 /home/devuser/workspace/wn7_dl_rep/sample.png: 512x640 1 Paper, 2 Rocks, 2 Scissorss, 55.0ms
# Speed: 4.6ms preprocess, 55.0ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/test/rps_test6
# Class: Scissors, Confidence: 0.8993
# Class: Rock, Confidence: 0.8862
# Class: Scissors, Confidence: 0.7631
# Class: Rock, Confidence: 0.6568
# Class: Paper, Confidence: 0.3890

# %%
result = model.predict('rsp1.jpg')
result[0].show()
# Out:
# image 1/1 /home/devuser/workspace/wn7_dl_rep/rsp1.jpg: 448x640 1 Paper, 1 Rock, 1 Scissors, 51.5ms
# Speed: 4.6ms preprocess, 51.5ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=800x533>
